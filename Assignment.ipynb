# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujaChintada/rgukt-/blob/master/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium 
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
nuzvid=folium.Map(location=[16.7850, 80.8488])
nuzvid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from branca.element import Figure
fig=Figure(width=550,height=350)
map1=folium.Map(location=[16.7850, 80.8488],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
fig2=Figure(width=850,height=550)
map2=folium.Map(location=[16.7850, 80.8488])
fig2.add_child(map2)
folium.TileLayer('Stamen Terrain').add_to(map2)
folium.TileLayer('Stamen Toner').add_to(map2)
folium.TileLayer('Stamen Water Color').add_to(map2)
folium.TileLayer('cartodbpositron').add_to(map2)
folium.TileLayer('cartodbdark_matter').add_to(map2)
folium.LayerControl().add_to(map2)
map2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Creating Basemap
fig3=Figure(width=550,height=350)
map3=folium.Map(location=[16.7850, 80.8488],tiles='cartodbdark_matter',zoom_start=8)
fig3.add_child(map3)

#Adding markers to the map

folium.Marker(location=[16.7850, 80.8488],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see nuzvid</strong>',icon=folium.features.CustomIcon("data:image/jpeg;base64,...",icon_size=(50,50))).add_to(map3)
folium.Marker(location=[18.4101,83.9030],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Srikakulam</strong>',icon=folium.features.CustomIcon("https://thumbs.dreamstime.com/b/train-logo-concept-icon-illustration-design-170455146.jpg",icon_size=(50,50))).add_to(map3)
map3
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coords = [[18.4091,83.9038],[18.3105,83.5683],[18.1116,83.3957],[17.7214, 83.2905],[17.6896,83.0024],[17.3573,82.5443]]
coords2  =[[17.2789,82.4013],[17.0453,82.1691],[17.0005,81.8040],[16.8971,81.6634],[16.8073,81.5316],[16.7107,81.0952],[16.5187,80.6200],[16.7850,80.8488]]

# %%
fig5=Figure(height=550,width=750)
map5=folium.Map(location=[16.7850,80.8488],tiles='cartodbdark_matter',zoom_start=7)
fig5.add_child(map5)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
f1=folium.FeatureGroup("route 1")
f2=folium.FeatureGroup("route 2")
line_1=folium.vector_layers.PolyLine(coords,popup='<b>Path1</b>',tooltip='path1',color='blue',weight=8).add_to(f1)
line_2=folium.vector_layers.PolyLine(coords2,popup='<b>Path2</b>',tooltip='path2',color='red',weight=8).add_to(f2)
folium.Marker(location=[18.4101,83.9030],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Srikakulam</strong>',icon=folium.features.CustomIcon("https://thumbs.dreamstime.com/b/train-logo-concept-icon-illustration-design-170455146.jpg",icon_size=(50,50))).add_to(map5)
folium.Marker(location=[17.7214,83.2905],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see vishakapatnam</strong>',icon=folium.features.CustomIcon("data:image/jpeg;base64,...",icon_size=(50,50))).add_to(map5)
folium.Marker(location=[17.3573,82.5443],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see tuni</strong>').add_to(map5)
folium.Marker(location=[17.2789,82.4013],popup='<h3 style="color:red;">Marker2</h3>',tooltip='<strong>Click here to see annavaram</strong>',icon=folium.features.CustomIcon("https://upload.wikimedia.org/wikipedia/commons/4/4a/AnnavaramTemple.jpg",icon_size=(50,50))).add_to(map5)
folium.Marker(location=[17.2789,82.4013],popup='<h3 style="color:blue;">Marker2</h3>',tooltip='<strong>Click here to see Rajuhmundry</strong>',icon=folium.features.CustomIcon("https://thumbs.dreamstime.com/b/godavari-river-flows-distance-kilometres-making-second-longest-river-india-ganges-town-230336990.jpg",icon_size=(50,50))).add_to(map5)
folium.Marker(location=[16.5187,80.6200],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Vijayawada junction</strong>').add_to(map5)
folium.Marker(location=[16.7850, 80.8488],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see nuzvid</strong>',icon=folium.features.CustomIcon("data:image/jpeg;base64,...",icon_size=(50,50))).add_to(map5)
f1.add_to(map5)
f2.add_to(map5)


folium.LayerControl().add_to(map5)
map5
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
